# %%
from PyDBDdim.utils import DimensionlessLearning
import torch
torch.manual_seed(0)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import warnings
warnings.filterwarnings("ignore")

# %%
#set save path

current_path = r"C:\Users\vvmil\Documents\Python_Vmil\Jupyter_Notebooks\Plasma_He_calcs\dimensionless_numbers_mb\limited_terms"

fig_base_terms_mb = current_path +r'\fig_base_terms_mb_no_test.pdf'

current_path = r"C:\Users\vvmil\Documents\Python_Vmil\Jupyter_Notebooks\Plasma_He_calcs\dimensionless_numbers_mb\limited_terms"
fig_base_avg_terms_mb = current_path +r'\fig_base_terms_avg_mb_no_test.pdf'
#fig_base_F_Kiz_terms_mb = current_path +r'fig_base_terms_F_Kiz_mb'
print(fig_base_terms_mb)
# Out:
# C:\Users\vvmil\Documents\Python_Vmil\Jupyter_Notebooks\Plasma_He_calcs\dimensionless_numbers_mb\limited_terms\fig_base_terms_mb_no_test.pdf

# %%
###### PLOTS HERE ######

import numpy as np
import matplotlib
import sys
sys.path.append("Users\vvmil\AppData\Local\Programs\MiKTeX")
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.preamble']=r'\usepackage{amsmath}'
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# Useful for running matplotlib on high-dpi displays

best_r2 = np.array([0.9997, 0.998, 0.985, 0.88, 0.65])
w_size = np.array([6,10,8,7,10])
#log_lg_set = [-3.52288, -3, -2.52288, -2 ,-1.5288]
lg_set = np.array([0.0003, 0.001, 0.003, 0.01, 0.03])

fig, [ax1, ax2] = plt.subplots(1, 2, sharey=False, figsize=(8, 4))


#variables: metric, lambda = lg_set, array_cardinality_dim1_w, array_cardinality_dim1_gamma. Check the gamma variable
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 16}

matplotlib.rc('font', **font)

ax1.semilogx(lg_set,best_r2, 'r-o', label = r"R$^2$ vs $\lambda_{gamma}$")
ax1.set_xlabel(r"$\lambda_1$")
#ax1.set_xticks(x_ext,labels=labels) # this is supposed to work, matplotlib is working on it
#ax1.set_xticks(x_ext)
#ax1.set_xticklabels([])
ax1.set_ylabel(r"Average R$^2$")
#ax1.set_ylim(7.9, 8.5)
#ax1.set_xlim(-0.2, 3.2)
#ax1.text(0, 3.3, r"a: NO$\mathrm{_2}\mathrm{^-}$", fontsize=12,
#         bbox=dict(boxstyle="square", ec=(0.0, 0.0, 0.0), fc=(1., 1, 1)))

#ax1.text(0, 2.5, r"$\mathrm{y =0.1372x+0.0704}$", fontsize=12)
#ax1.text(0, 2, r"$\mathrm{R^2 = 0.9966}$", fontsize=12)
#         bbox=dict(boxstyle="square", ec=(0.0, 0.0, 0.0), fc=(1., 1, 1)))


ax2.semilogx(lg_set,w_size, '-o', label = r"$||\gamma||_0$ vs $\lambda_{gamma}$")

ax2.set_ylabel(r"Average $|\boldsymbol{w}_\Pi|_0$")
ax2.set_xlabel(r"$\lambda_1$")

fig.tight_layout(pad=0.8)

#ax1.yaxis.labelpad=10.0
#fig.suptitle(r'Dimensionless Regression with Mass Balance Base Terms', fontsize=16, y=.95)


#plt.savefig(fig_base_terms_mb)

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 35]

# Create the plot
fig, ax1 = plt.subplots()

# Plot the data
ax1.plot(x, y, marker='o')
ax1.set_xlabel('Primary X-axis labels')

# Create a second x-axis below the first
ax2 = ax1.twiny()
ax2.xaxis.set_ticks_position('bottom')  # Set the position of the second x-axis
ax2.xaxis.set_label_position('bottom')  # Set the position of the second x-axis label
ax2.spines['bottom'].set_position(('outward', 40))  # Offset the second x-axis

# Set the labels for the second x-axis
ax2.set_xlabel('Secondary X-axis labels')
ax2.set_xticks(x)
ax2.set_xticklabels(['A', 'B', 'C', 'D', 'E'])

# Show the plot
plt.show()

# %%
###### PLOTS HERE ######

import numpy as np
import matplotlib
import sys
sys.path.append("Users\vvmil\AppData\Local\Programs\MiKTeX")
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.preamble']=r'\usepackage{amsmath}'
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# Useful for running matplotlib on high-dpi displays

best_r2 = np.array([0.906, 0.8886, 0.846, 0.686, 0.28])
w_size = np.array([9.32,8.8,8.8,8.7,8.86])
#log_lg_set = [-3.52288, -3, -2.52288, -2 ,-1.5288]
lg_set = np.array([0.0001, 0.0003, 0.001, 0.003, 0.01])

fig, [ax1, ax2] = plt.subplots(1, 2, sharey=False, figsize=(8, 4))


#variables: metric, lambda = lg_set, array_cardinality_dim1_w, array_cardinality_dim1_gamma. Check the gamma variable
font = {'family' : 'Arial',
        'weight' : 'bold',
        'size'   : 20}

plt.rcParams['font.family'] = 'Calibri'

ax1.semilogx(lg_set,best_r2, 'r-o', label = r"\textbf{R}$^{\boldsymbol{2}}$ vs $\boldsymbol{\lambda_{gamma}}$")
ax1.set_xlabel(r"$\boldsymbol{\lambda_1}$")
#ax1.set_xticks(x_ext,labels=labels) # this is supposed to work, matplotlib is working on it
#ax1.set_xticks(x_ext)
#ax1.set_xticklabels([])
ax1.set_ylabel(r"\textbf{Average R}$^{\boldsymbol{2}}$")
#ax1.set_ylim(7.9, 8.5)
#ax1.set_xlim(-0.2, 3.2)
#ax1.text(0, 3.3, r"a: NO$\mathrm{_2}\mathrm{^-}$", fontsize=12,
#         bbox=dict(boxstyle="square", ec=(0.0, 0.0, 0.0), fc=(1., 1, 1)))

#ax1.text(0, 2.5, r"$\mathrm{y =0.1372x+0.0704}$", fontsize=12)
#ax1.text(0, 2, r"$\mathrm{R^2 = 0.9966}$", fontsize=12)
#         bbox=dict(boxstyle="square", ec=(0.0, 0.0, 0.0), fc=(1., 1, 1)))


ax2.semilogx(lg_set,w_size, '-o', label = r"$||\gamma||_0$ vs $\lambda_{gamma}$")

ax2.set_ylabel(r"\textbf{Average }$|\boldsymbol{w}_{\boldsymbol{\Pi}}|_{\boldsymbol{0}}$")
ax2.set_xlabel(r"$\boldsymbol{\lambda_1}$")

fig.tight_layout(pad=0.8)

#ax1.yaxis.labelpad=10.0
#fig.suptitle(r'Dimensionless Regression with Mass Balance Base Terms + Flowrate', fontsize=16, y=.95)


plt.savefig(fig_base_avg_terms_mb)

# %%
#set save path

current_path = r"C:\Users\vvmil\Documents\Python_Vmil\Jupyter_Notebooks\Plasma_He_calcs\dimensionless_numbers_energy\base_terms\dim1_order1"

fig_base_terms_eb = current_path +r'\fig_base_terms_eb_no_test.pdf'

fig_base_avg_terms_eb = current_path +r'\fig_base_terms_avg_eb_no_test.pdf'

print(fig_base_terms_mb)
# Out:
# C:\Users\vvmil\Documents\Python_Vmil\Jupyter_Notebooks\Plasma_He_calcs\dimensionless_numbers_mb\limited_terms\fig_base_terms_mb_no_test.pdf

# %%
###### PLOTS HERE ######

import numpy as np
import matplotlib
import sys
sys.path.append("Users\vvmil\AppData\Local\Programs\MiKTeX")
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.preamble']=r'\usepackage{amsmath}'
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# Useful for running matplotlib on high-dpi displays

best_r2 = np.array([0.999, 0.9999, 0.9997, 0.994, 0.959, 0.663])
w_size = np.array([12,15,16,13,14,18])
#log_lg_set = [-3.52288, -3, -2.52288, -2 ,-1.5288]
lg_set = np.array([0.003, 0.01, 0.03,0.1,0.3,1])

fig, [ax1, ax2] = plt.subplots(1, 2, sharey=False, figsize=(8, 4))


#variables: metric, lambda = lg_set, array_cardinality_dim1_w, array_cardinality_dim1_gamma. Check the gamma variable


ax1.semilogx(lg_set,best_r2, 'r-o', label = r"R$^2$ vs $\lambda_{gamma}$")
ax1.set_xlabel(r"$\lambda_1$")
#ax1.set_xticks(x_ext,labels=labels) # this is supposed to work, matplotlib is working on it
#ax1.set_xticks(x_ext)
#ax1.set_xticklabels([])
ax1.set_ylabel(r"Average R$^2$")
#ax1.set_ylim(7.9, 8.5)
#ax1.set_xlim(-0.2, 3.2)
#ax1.text(0, 3.3, r"a: NO$\mathrm{_2}\mathrm{^-}$", fontsize=12,
#         bbox=dict(boxstyle="square", ec=(0.0, 0.0, 0.0), fc=(1., 1, 1)))

#ax1.text(0, 2.5, r"$\mathrm{y =0.1372x+0.0704}$", fontsize=12)
#ax1.text(0, 2, r"$\mathrm{R^2 = 0.9966}$", fontsize=12)
#         bbox=dict(boxstyle="square", ec=(0.0, 0.0, 0.0), fc=(1., 1, 1)))


ax2.semilogx(lg_set,w_size, '-o', label = r"$||\gamma||_0$ vs $\lambda_{gamma}$")

ax2.set_ylabel(r"Average $|\boldsymbol{w}_\Pi|_0$")
ax2.set_xlabel(r"$\lambda_1$")



#ax1.yaxis.labelpad=10.0
#fig.suptitle(r'Dimensionless Regression with Energy Balance Base Terms', fontsize=16, y=.95)


plt.savefig(fig_base_terms_eb)

# %%
###### PLOTS HERE ######

import numpy as np
import matplotlib
import sys
sys.path.append("Users\vvmil\AppData\Local\Programs\MiKTeX")
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.preamble']=r'\usepackage{amsmath}'
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# Useful for running matplotlib on high-dpi displays

best_r2 = np.array([0.9989, 0.9992, 0.9989, 0.99, 0.93, 0.54])
w_size = np.array([13,13.5,13,12.5,11.75,13.8])
#log_lg_set = [-3.52288, -3, -2.52288, -2 ,-1.5288]
lg_set = np.array([0.003, 0.01, 0.03,0.1,0.3,1])

fig, [ax1, ax2] = plt.subplots(1, 2, sharey=False, figsize=(8, 4))


#variables: metric, lambda = lg_set, array_cardinality_dim1_w, array_cardinality_dim1_gamma. Check the gamma variable


ax1.semilogx(lg_set,best_r2, 'r-o', label = r"R$^2$ vs $\lambda_{gamma}$")
ax1.set_xlabel(r"$\lambda_1$")
#ax1.set_xticks(x_ext,labels=labels) # this is supposed to work, matplotlib is working on it
#ax1.set_xticks(x_ext)
#ax1.set_xticklabels([])
ax1.set_ylabel(r"Average R$^2$")
#ax1.set_ylim(7.9, 8.5)
#ax1.set_xlim(-0.2, 3.2)
#ax1.text(0, 3.3, r"a: NO$\mathrm{_2}\mathrm{^-}$", fontsize=12,
#         bbox=dict(boxstyle="square", ec=(0.0, 0.0, 0.0), fc=(1., 1, 1)))

#ax1.text(0, 2.5, r"$\mathrm{y =0.1372x+0.0704}$", fontsize=12)
#ax1.text(0, 2, r"$\mathrm{R^2 = 0.9966}$", fontsize=12)
#         bbox=dict(boxstyle="square", ec=(0.0, 0.0, 0.0), fc=(1., 1, 1)))


ax2.semilogx(lg_set,w_size, '-o', label = r"$|\boldsymbol{\gamma}|_0$ vs $\lambda_{gamma}$")

ax2.set_ylabel(r"Average $|\boldsymbol{w}_{\Pi}|_0$")
ax2.set_xlabel(r"$\lambda_1$")

fig.tight_layout(pad=1.3)

#ax1.yaxis.labelpad=10.0
#fig.suptitle(r'Dimensionless Regression with Energy Balance Base Terms', fontsize=16, y=.95)


plt.savefig(fig_base_avg_terms_eb)

# %%
import os
import pandas as pd
import numpy as np

def process_excel_files(folder_path, sheet_name = 'ext dimension number'):
    results = {}
    
    #what will be stored in results in each iteration...
    
    lam_list = []
    
    top_test = {'val_r2' : [],
                'test_r2' : [],
                'card_w' : []
               }
    
    top_val = {'val_r2': [],
               'test_r2':[],
               'card_w':[]
              }
    
    sub_top_val ={'val_r2': [],
               'test_r2':[],
               'card_w':[]
              }
    
    top_5 = {'val_r2': [],
               'test_r2':[],
               'card_w':[]
              }
    
    converged = {'val_r2': [],
               'test_r2':[],
               'card_w':[]
              }
    
    frac = {'frac': [],
               'card_w':[]
            }
    
    
    # Check if the provided path is a directory
    if not os.path.isdir(folder_path):
        print(f"The path '{folder_path}' is not a valid directory.")
        return results

    # Iterate through each folder in the directory
    for subfolder in os.listdir(folder_path):
        subfolder_path = os.path.join(folder_path, subfolder)
        if os.path.isdir(subfolder_path):
            # Look for Excel files in the subfolder
            
                       
            for file in os.listdir(subfolder_path):
                if file.endswith('.xlsx'):
                    excel_path = os.path.join(subfolder_path, file)
                    # Read the Excel file and access the desired sheet
                    df = pd.read_excel(excel_path, sheet_name=sheet_name)
                    # Store values from specific columns
                    #for index, row in df.iterrows():
                    card_w = df['cardinality_of_w_dim1'].to_numpy()
                    val = df['r2'].to_numpy()
                    test = df['r2_ext_test'].to_numpy()
                    lam = df['lambda'].to_numpy()
                    
                    lam_list.append(np.max(lam))
                    
                    #for top test score
                    a = np.argmax(test)
                    top_test['val_r2'].append(val[a])
                    top_test['test_r2'].append(test[a])
                    top_test['card_w'].append(card_w[a])
                    
                    #for top validation scorer
                    a = np.argmax(val)
                    top_val['val_r2'].append(val[a])
                    top_val['test_r2'].append(test[a])
                    top_val['card_w'].append(card_w[a])
                    
                    # for substitutes
                    # we want the top TEST value out of the validation scores that exceed 0.999.
                    
                    threshold = np.max(val)*0.99
                    b = val>=threshold
                    a = np.argmax(test*b) #the only test values that are multiplied by 1 are where the val > threshold
                    
                    # if we failed to get an index where the validation is above the threshold, 
                    # then a will return zero. In that case, just give me the top performer for now.
                    if a ==0 and val[a]<threshold:
                        a = np.argmax(val)
                        sub_top_val['val_r2'].append(val[a])
                        sub_top_val['test_r2'].append(test[a])
                        sub_top_val['card_w'].append(card_w[a])
                    else:
                        # note we keep a value what it was beofre the ii
                        sub_top_val['val_r2'].append(val[a])
                        sub_top_val['test_r2'].append(test[a])
                        sub_top_val['card_w'].append(card_w[a])
                        
                        
                    
                    # for top 5 val scores
                    a = np.argsort(val)[-4:] # we sort it from smallest to largest, take last 5
                    top_5['val_r2'].append(np.mean(val[a]))
                    top_5['test_r2'].append(np.mean(test[a]))
                    top_5['card_w'].append(np.mean(card_w[a]))
                    
                    
                    # for converged
                    threshold = 0.9
                    a = val>=threshold
                    print('number of val over threshold is', a)
                    converged['val_r2'].append(np.mean(val[a]))
                    converged['test_r2'].append(np.mean(test[a]))
                    converged['card_w'].append(np.mean(card_w[a]))
                    
                    # fractional: what frac of dim #s that surpassed threshold had test nums that surpassed threshold?
                    threshold = 0.9
                    good_val = val>= threshold
                    count_good_val = np.sum(good_val)
                    good_test = test>=threshold
                    good_val_test = good_test*good_val #we want all of the val numbers > threshold that have tests > threshold
                    count_good_val_test = np.sum(good_val_test)
                    if count_good_val > 0:
                        fraction = count_good_val_test/count_good_val
                        frac['frac'].append(fraction)
                        frac['card_w'].append(np.mean(card_w[good_val_test]))
                    else:
                        fraction == 0
                        frac['frac'].append(fraction)
                        frac['card_w'].append(11)
                    
    results = {'lambda' : lam_list,
            'top_test' : top_test,
           'top_val' : top_val,
            'sub_top_val' : sub_top_val,
            'top_5'  : top_5,
            'converged' : converged,
            'frac': frac
           }

    return results

# Example usage
folder_path = r'C:\Users\vvmil\Documents\Python_Vmil\Jupyter_Notebooks\Plasma_He_calcs\He_code_new\dim_num_eb_val_test\unpacked\6_terms'
data = process_excel_files(folder_path)
print(data)
# Out:
# number of val over threshold is [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# number of val over threshold is [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# number of val over threshold is [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# number of val over threshold is [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# number of val over threshold is [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# number of val over threshold is [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# number of val over threshold is [False  True  True False  True  True  True  True  True  True  True  True
#  False  True  True  True  True  True  True  True  True  True  True  True
#   True]
# {'lambda': [0.0003, 0.001, 0.003, 0.01, 0.03, 0.1, 0.3], 'top_test': {'val_r2': [0.9952557711528989, 0.9963591371586878, 0.9989441800511915, 0.9985246989657186, 0.997795461125051, 0.9941515711513639, 0.90987041434017], 'test_r2': [0.986694846170207, 0.9832245180677425, 0.9998431316038876, 0.9983111483285001, 0.9207823298746016, 0.994963132615273, -1.202980824847926], 'card_w': [9, 9, 6, 5, 5, 5, 6]}, 'top_val': {'val_r2': [0.9997546787031478, 0.9997672112125187, 0.9998078102087017, 0.9995469425876569, 0.9979473085518805, 0.9941515711513639, 0.9398139185042118], 'test_r2': [0.6234239245861952, 0.7723083902428998, 0.4546869133031675, 0.969766168234283, 0.9180928914819015, 0.994963132615273, -1.552037809969178], 'card_w': [3, 3, 3, 3, 5, 5, 5]}, 'sub_top_val': {'val_r2': [0.9952557711528989, 0.9963591371586878, 0.9989441800511915, 0.9985246989657186, 0.997795461125051, 0.9941515711513639, 0.9398139185042118], 'test_r2': [0.986694846170207, 0.9832245180677425, 0.9998431316038876, 0.9983111483285001, 0.9207823298746016, 0.994963132615273, -1.552037809969178], 'card_w': [9, 9, 6, 5, 5, 5, 5]}, 'top_5': {'val_r2': [0.9997272024097158, 0.9996697183016485, 0.9997171753206713, 0.9991059352272745, 0.9979417639227833, 0.9924787746932883, 0.939370750549051], 'test_r2': [0.7731847086733501, 0.4353631799703937, 0.6917658688658284, 0.8671137703486238, 0.9138898448992061, 0.6556425890509514, -1.5156534991919286], 'card_w': [3.0, 3.0, 3.5, 4.5, 5.0, 5.0, 5.0]}, 'converged': {'val_r2': [0.9953196128140133, 0.9977847946126094, 0.9986327066146666, 0.9987340307419513, 0.9978360894905661, 0.9890980382095034, 0.9374716387132657], 'test_r2': [0.7684479850330236, 0.6469676647672947, 0.7793357070437947, 0.9177101408112937, 0.9126230907629117, 0.5115819220239608, -1.5230510751649466], 'card_w': [6.083333333333333, 5.166666666666667, 5.791666666666667, 5.0, 5.0, 5.166666666666667, 5.045454545454546]}, 'frac': {'frac': [0.25, 0.125, 0.20833333333333334, 0.6666666666666666, 1.0, 0.08333333333333333, 0.0], 'card_w': [9.666666666666666, 9.0, 7.2, 5.0, 5.0, 7.0, nan]}}
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
g = np.array([1,1,1])
np.mean(g[False, False, False])
# Out:
# nan

# %%
import matplotlib
import matplotlib.pyplot as plt

def plot_dict_vs_list(data_dict, x_list, y_titles, x_titles, sup_titles):
    if len(x_list) != len(next(iter(data_dict.values()))):
        print("Error: The length of the list must match the length of the dictionary's vectors.")
        return
    
    import sys
    sys.path.append("Users\vvmil\AppData\Local\Programs\MiKTeX")
    matplotlib.rcParams['text.usetex'] = True
    matplotlib.rcParams['text.latex.preamble']=r'\usepackage{amsmath}'
    import matplotlib.pyplot as plt
    # %matplotlib inline
    # %config InlineBackend.figure_format='retina'
    
    num_keys = len(data_dict)
    
    #fig, ["ax"+str(i) for i in range(1, num_keys+1)]
    fig, axes = plt.subplots(1, num_keys, sharey=False, figsize=(8, 4))
    font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 16}
    matplotlib.rc('font', **font)

    i = 0
    
    for key, y_vector in data_dict.items():
        
        y_vector = np.array(y_vector)
        axes[i].semilogx(x_list,np.where(y_vector > 0*y_vector,y_vector, 0*y_vector) , 'r-o', label = r"R$^2$ vs $\lambda_{gamma}$")
        axes[i].set_xlabel(x_titles[i])
        #ax1.set_xticks(x_ext,labels=labels) # this is supposed to work, matplotlib is working on it
        #ax1.set_xticks(x_ext)
        #ax1.set_xticklabels([])
        axes[i].set_ylabel(y_titles[i])
        axes[i].set_title(key)
        #ax1.set_ylim(7.9, 8.5)
        #ax1.set_xlim(-0.2, 3.2)
        #ax1.text(0, 3.3, r"a: NO$\mathrm{_2}\mathrm{^-}$", fontsize=12,
        #         bbox=dict(boxstyle="square", ec=(0.0, 0.0, 0.0), fc=(1., 1, 1)))

        #ax1.text(0, 2.5, r"$\mathrm{y =0.1372x+0.0704}$", fontsize=12)
        #ax1.text(0, 2, r"$\mathrm{R^2 = 0.9966}$", fontsize=12)
        #         bbox=dict(boxstyle="square", ec=(0.0, 0.0, 0.0), fc=(1., 1, 1)))
        i = i+1
    fig.tight_layout(pad=0.8)
    fig.suptitle(sup_titles, **font)
    plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust the subplots to make room for the suptitle


x_titles = [r"$\lambda_1$",r"$\lambda_1$", r"$\lambda_1$"]
y_titles = [r"$R^2$" , r"$R^2$", r"$|\boldsymbol{w}_{\Pi}|_0$"]


folder_path = r'C:\Users\vvmil\Documents\Python_Vmil\Jupyter_Notebooks\Plasma_He_calcs\He_code_new\dim_num_eb_val_test\unpacked\6_terms'
data = process_excel_files(folder_path)
print(data)
# plot_dict_vs_list(data['top_test'], data['lambda'], y_titles, x_titles, r'Dim Num from Top Test Score')
# plot_dict_vs_list(data['top_val'], data['lambda'], y_titles, x_titles, r'Dim Num from Top Val Score')
# plot_dict_vs_list(data['sub_top_val'], data['lambda'], y_titles, x_titles, r'Dim Num from Best Test of Top Val Scores')
# plot_dict_vs_list(data['top_5'], data['lambda'], y_titles, x_titles, r'Dim Num from Top 5 Val Score')
# plot_dict_vs_list(data['converged'], data['lambda'], y_titles, x_titles, r'Dim Num from Converged Val Scores')
# plot_dict_vs_list(data['frac'], data['lambda'], ['hit rate', r"$|\boldsymbol{w}_{\Pi}|_0$"], [r"$\lambda_1$",r"$\lambda_1$"], r'Dim Num Where Val > 0.9, Test > 0.9'  )
# Out:
# number of val over threshold is [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# number of val over threshold is [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# number of val over threshold is [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# number of val over threshold is [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# number of val over threshold is [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# number of val over threshold is [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# number of val over threshold is [False  True  True False  True  True  True  True  True  True  True  True
#  False  True  True  True  True  True  True  True  True  True  True  True
#   True]
# {'lambda': [0.0003, 0.001, 0.003, 0.01, 0.03, 0.1, 0.3], 'top_test': {'val_r2': [0.9952557711528989, 0.9963591371586878, 0.9989441800511915, 0.9985246989657186, 0.997795461125051, 0.9941515711513639, 0.90987041434017], 'test_r2': [0.986694846170207, 0.9832245180677425, 0.9998431316038876, 0.9983111483285001, 0.9207823298746016, 0.994963132615273, -1.202980824847926], 'card_w': [9, 9, 6, 5, 5, 5, 6]}, 'top_val': {'val_r2': [0.9997546787031478, 0.9997672112125187, 0.9998078102087017, 0.9995469425876569, 0.9979473085518805, 0.9941515711513639, 0.9398139185042118], 'test_r2': [0.6234239245861952, 0.7723083902428998, 0.4546869133031675, 0.969766168234283, 0.9180928914819015, 0.994963132615273, -1.552037809969178], 'card_w': [3, 3, 3, 3, 5, 5, 5]}, 'sub_top_val': {'val_r2': [0.9952557711528989, 0.9963591371586878, 0.9989441800511915, 0.9985246989657186, 0.997795461125051, 0.9941515711513639, 0.9398139185042118], 'test_r2': [0.986694846170207, 0.9832245180677425, 0.9998431316038876, 0.9983111483285001, 0.9207823298746016, 0.994963132615273, -1.552037809969178], 'card_w': [9, 9, 6, 5, 5, 5, 5]}, 'top_5': {'val_r2': [0.9997272024097158, 0.9996697183016485, 0.9997171753206713, 0.9991059352272745, 0.9979417639227833, 0.9924787746932883, 0.939370750549051], 'test_r2': [0.7731847086733501, 0.4353631799703937, 0.6917658688658284, 0.8671137703486238, 0.9138898448992061, 0.6556425890509514, -1.5156534991919286], 'card_w': [3.0, 3.0, 3.5, 4.5, 5.0, 5.0, 5.0]}, 'converged': {'val_r2': [0.9953196128140133, 0.9977847946126094, 0.9986327066146666, 0.9987340307419513, 0.9978360894905661, 0.9890980382095034, 0.9374716387132657], 'test_r2': [0.7684479850330236, 0.6469676647672947, 0.7793357070437947, 0.9177101408112937, 0.9126230907629117, 0.5115819220239608, -1.5230510751649466], 'card_w': [6.083333333333333, 5.166666666666667, 5.791666666666667, 5.0, 5.0, 5.166666666666667, 5.045454545454546]}, 'frac': {'frac': [0.25, 0.125, 0.20833333333333334, 0.6666666666666666, 1.0, 0.08333333333333333, 0.0], 'card_w': [9.666666666666666, 9.0, 7.2, 5.0, 5.0, 7.0, nan]}}
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
folder_path = r'C:\Users\vvmil\Documents\Python_Vmil\Jupyter_Notebooks\Plasma_He_calcs\He_code_new\dim_num_eb_val_test\packed\6_rates'
data = process_excel_files(folder_path)


x_titles = [r"$\lambda_1$",r"$\lambda_1$", r"$\lambda_1$"]
y_titles = [r"$R^2$" , r"$R^2$", r"$|\boldsymbol{w}_{\Pi}|_0$"]


plot_dict_vs_list(data['top_test'], data['lambda'], y_titles, x_titles, r'Dim Num from Top Test Score')
plot_dict_vs_list(data['top_val'], data['lambda'], y_titles, x_titles, r'Dim Num from Top Val Score')
plot_dict_vs_list(data['sub_top_val'], data['lambda'], y_titles, x_titles, r'Dim Num from Best Test of Top Val Scores')
plot_dict_vs_list(data['top_5'], data['lambda'], y_titles, x_titles, r'Dim Num from Top 5 Val Score')
plot_dict_vs_list(data['converged'], data['lambda'], y_titles, x_titles, r'Dim Num from Converged Val Scores')
plot_dict_vs_list(data['frac'], data['lambda'], ['hit rate', r"$|\boldsymbol{w}_{\Pi}|_0$"], [r"$\lambda_1$",r"$\lambda_1$"], r'Dim Num Where Val > 0.9, Test > 0.9'  )
# Out:
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\vvmil\AppData\Local\Temp\ipykernel_6304\4033753112.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   fraction = count_good_val_test/count_good_val

# %%
print(data['frac'])
# Out:
# {'frac': [0.9166666666666666, 0.8333333333333334, 0.8181818181818182, 1.0, 1.0, 0.0, nan], 'card_w': [4.636363636363637, 4.6, 4.111111111111111, 3.5, 4.25, nan, nan]}

# %%
folder_path = r'C:\Users\vvmil\Documents\Python_Vmil\Jupyter_Notebooks\Plasma_He_calcs\He_code_new\dim_num_mb_val_test\packed\6_rates'
data = process_excel_files(folder_path)


x_titles = [r"$\lambda_1$",r"$\lambda_1$", r"$\lambda_1$"]
y_titles = [r"$R^2$" , r"$R^2$", r"$|\boldsymbol{w}_{\Pi}|_0$"]


plot_dict_vs_list(data['top_test'], data['lambda'], y_titles, x_titles, r'Dim Num from Top Test Score')
plot_dict_vs_list(data['top_val'], data['lambda'], y_titles, x_titles, r'Dim Num from Top Val Score')
plot_dict_vs_list(data['sub_top_val'], data['lambda'], y_titles, x_titles, r'Dim Num from Best Test of Top Val Scores')
plot_dict_vs_list(data['top_5'], data['lambda'], y_titles, x_titles, r'Dim Num from Top 5 Val Score')
plot_dict_vs_list(data['converged'], data['lambda'], y_titles, x_titles, r'Dim Num from Converged Val Scores')
plot_dict_vs_list(data['frac'], data['lambda'], ['hit rate', r"$|\boldsymbol{w}_{\Pi}|_0$"], [r"$\lambda_1$",r"$\lambda_1$"], r'Dim Num Where Val > 0.9, Test > 0.9'  )
# Out:
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
folder_path = r'C:\Users\vvmil\Documents\Python_Vmil\Jupyter_Notebooks\Plasma_He_calcs\He_code_new\dim_num_mb_val_test\unpacked\6&7_rates'
data = process_excel_files(folder_path)


x_titles = [r"$\lambda_1$",r"$\lambda_1$", r"$\lambda_1$"]
y_titles = [r"$R^2$" , r"$R^2$", r"$|\boldsymbol{w}_{\Pi}|_0$"]


plot_dict_vs_list(data['top_val'], data['lambda'], y_titles, x_titles, r'Dim Num from Top Val Score')
plot_dict_vs_list(data['sub_top_val'], data['lambda'], y_titles, x_titles, r'Dim Num from Best Test of Top Val Scores')
plot_dict_vs_list(data['top_5'], data['lambda'], y_titles, x_titles, r'Dim Num from Top 5 Val Score')
plot_dict_vs_list(data['converged'], data['lambda'], y_titles, x_titles, r'Dim Num from Converged Val Scores')
plot_dict_vs_list(data['frac'], data['lambda'], ['hit rate', r"$|\boldsymbol{w}_{\Pi}|_0$"], [r"$\lambda_1$",r"$\lambda_1$"], r'Dim Num Where Val > 0.9, Test > 0.9'  )
# Out:
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\vvmil\AppData\Local\Temp\ipykernel_6304\4033753112.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   fraction = count_good_val_test/count_good_val
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\vvmil\AppData\Local\Temp\ipykernel_6304\4033753112.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   fraction = count_good_val_test/count_good_val
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\vvmil\anaconda3\envs\research\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\vvmil\AppData\Local\Temp\ipykernel_6304\4033753112.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   fraction = count_good_val_test/count_good_val

# %%
data['top_val'].items()[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 data['top_val'].items()[0]
#
# TypeError: 'dict_items' object is not subscriptable
