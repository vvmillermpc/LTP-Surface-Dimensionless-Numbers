# %%
import numpy as np
import scipy.integrate as integrate
import matplotlib.pyplot as plt
import scipy.optimize as sopt
import pandas as pd
import os
from pyomo.environ import *
from idaes.core.solvers import get_solver
import pandas as pd

# %%
# got it means that it is in the excel sheet already

# Q_a = float(Qa[index])   #got it
# Q_b = float(Qb[index])   # got it
# T_e = Te[index]          # got it
# t_a = float(time_col[index,0]) #seconds    got it
# t_b = float(time_col[index,1]) #seconds    got it
# t_c = float(1/freq[index]-t_a-t_b)        #will be calculated in place
# t_b = t_c+t_b                             # will be calcullated in place
# V_p_ta = float(Vipa[index]/t_a) #volts  #will be calculated in place
# V_p_tb = float(Vipb[index]/(t_b+t_c))  #volts   # will be calculated in place
# V_p_tc = 0.0                                   # will be assigned in place
# Flow = flowrate[index]*6*(10**-5)-0.0001 #convert from % to m^3/s, see exccel "flow_calibration..."
# E = float(E_abs[index])                       # got it
# ns = width_ns[index]                          # got it
# temp_C_gas = temp_C[index]                    # will be set.
# frequency = freq[index]                       # got it
# volt = voltage[index]                         #got it
# sign = signature[index]                       # got it

# %%
from PyDBDdim.utils import DatasetProcess
DBD = DatasetProcess(r"C:\Users\vvmil\Documents\Python_Vmil\Jupyter_Notebooks\Plasma_He_calcs_cleanup\data\data_no_packing_all\all_cm_no_packing")
signature_list = DBD.folder_col
time_col, _= DBD.current_segment()
time_col = np.array(time_col)
t_index = np.array(_)
Vipab, Qab = DBD.get_two_region_VI()
Pabs_kj = DBD.int_power #this is actually worthless but just being complete.
E_abs = DBD.get_plasma_E() #joules?
#print(Vipab)
#print(Qab)
#print(time_col)
#print(_)
#print(signature_list)

Vipa = np.reshape(Vipab[:,0],(Vipab.shape[0],1))
Vipb = np.reshape(Vipab[:,1],(Vipab.shape[0],1))
Qa = np.reshape(Qab[:,0],(Qab.shape[0],1))
Qb = np.reshape(Qab[:,1],(Qab.shape[0],1))
t_a = np.reshape(time_col[:,0],(Qab.shape[0],1))
t_b = np.reshape(time_col[:,1],(Qab.shape[0],1))
Pabs_kj = np.reshape(Pabs_kj, (Pabs_kj.shape[0],1))
E_abs = np.reshape(E_abs, (E_abs.shape[0],1))
print(Pabs_kj.shape)
print(t_a.shape)
print(t_b.shape)
print(Qa.shape)
print(Qb.shape)
print(Vipa.shape)
print(Vipb.shape)
print(E_abs.shape)



matrix = np.hstack((Vipa, Vipb, Qa, Qb, Pabs_kj, E_abs, t_a, t_b))
variables = ['Vipa_Vs', 'Vipb_Vs', 'Qa_As', 'Qb_As', 'Pabs_kJ','E_abs','ta_s', 'tb_s']
# Out:
# (128, 1)
# (128, 1)
# (128, 1)
# (128, 1)
# (128, 1)
# (128, 1)
# (128, 1)
# (128, 1)

# %%
print(matrix.shape)
print(Qa.shape)
print(Vipa.shape)
# Out:
# (128, 8)
# (128, 1)
# (128, 1)

# %%
print(signature_list)
# Out:
# ['OES_20231013155508', 'OES_20231013162821', 'OES_20231013163651', 'OES_20231013164453', 'OES_20231013165342', 'OES_20231013170219', 'OES_20231013171022', 'OES_20231013171848', 'OES_20231013173923', 'OES_20231013174758', 'OES_20231013175708', 'OES_20231013180609', 'OES_20231013181507', 'OES_20231013182414', 'OES_20231014161634', 'OES_20231014162507', 'OES_20231014163744', 'OES_20231014164607', 'OES_20231014165707', 'OES_20231014171138', 'OES_20231014172028', 'OES_20231014172905', 'OES_20231014175132', 'OES_20231014180056', 'OES_20231014180833', 'OES_20231014181819', 'OES_20231014182645', 'OES_20231014184127', 'OES_20231014184855', 'OES_20231014213853', 'OES_20231014214741', 'OES_20231014215646', 'OES_20231014220428', 'OES_20231014222348', 'OES_20231014223648', 'OES_20231014224420', 'OES_20231014225133', 'OES_20231014230141', 'OES_20231014231110', 'OES_20231014232017', 'OES_20231014232833', 'OES_20231014233622', 'OES_20231014234418', 'OES_20231014235302', 'OES_20231015001744', 'OES_20231015002641', 'OES_20231015003323', 'OES_20231015004114', 'OES_20231015222053', 'OES_20231015222610', 'OES_20231015230157', 'OES_20231015230932', 'OES_20231015231440', 'OES_20231016001751', 'OES_20231016002659', 'OES_20231016003740', 'OES_20231016004654', 'OES_20231016005631', 'OES_20231016202523', 'OES_20231016203644', 'OES_20231016204717', 'OES_20231016205717', 'OES_20231016210729', 'OES_20231016211454', 'OES_20231016212624', 'OES_20231016213722', 'OES_20231016214533', 'OES_20231016220141', 'OES_20231016221002', 'OES_20231016222057', 'OES_20231016224307', 'OES_20231016225458', 'OES_20231016230621', 'OES_20231016232847', 'OES_20231017125749', 'OES_20231017130922', 'OES_20231017131708', 'OES_20231017134507', 'OES_20231017135350', 'OES_20231017140403', 'OES_20231017141538', 'OES_20231017142438', 'OES_20231017161126', 'OES_20231017162137', 'OES_20231017163243', 'OES_20231017171317', 'OES_20231017172255', 'OES_20231017173128', 'OES_20231017174107', 'OES_20231017175010', 'OES_20231017182130', 'OES_20231017183006', 'OES_20231017222652', 'OES_20231017223657', 'OES_20231017224947', 'OES_20231017230006', 'OES_20231017232038', 'OES_20231017234337', 'OES_20231018140510', 'OES_20231018141539', 'OES_20231018145805', 'OES_20231018150751', 'OES_20231018151858', 'OES_20231018152844', 'OES_20231018153713', 'OES_20231018154740', 'OES_20231018155646', 'OES_20231018162007', 'OES_20231018163415', 'OES_20231018165129', 'OES_20231018171315', 'OES_20231018175256', 'OES_20231018180108', 'OES_20231018180921', 'OES_20231018181810', 'OES_20231018182729', 'OES_20231018183604', 'OES_20231018184405', 'OES_20231018185533', 'OES_20231018190627', 'OES_20231018191512', 'OES_20231018192709', 'OES_20231018200236', 'OES_20231018201609', 'OES_20231018202424', 'OES_20231018203543', 'OES_20231018204405', 'OES_20231018205411']

# %%
# Put this in three parts:
#1) generate data frame from data above
#2) generate data frame from existing excel with data inputs and Temperature
#3) delete redundant, empty columns in old excel
#4) pd.merg the data frames
#5) load into a new excel


#1 df
df0 = pd.DataFrame(data=matrix,columns=[variables[i] for i in range(0,len(variables))]) #first sheet, list dimension vector
df0['signature_dbd'] = signature_list
#df1 = pd.DataFrame(data=signature_list,columns=['signature']) #second sheet, list nullspace vectors and associated variables



# df from existing excel

file_path = r"C:\Users\vvmil\Documents\Python_Vmil\Jupyter_Notebooks\Plasma_He_calcs_cleanup\data\data_no_packing_all\data_col_vvm.xlsx"
df1 = pd.read_excel(file_path,sheet_name = r"no packing--good")  #, sheet_name = r"3cm_23mm_good"
df1 = df1.drop(columns = variables, errors = 'ignore')

#merge them
merged_df = pd.merge(df1, df0, left_on="signature", right_on="signature_dbd", how="inner")

merged_df.to_excel(
    r"C:\Users\vvmil\Documents\Python_Vmil\Jupyter_Notebooks\Plasma_He_calcs_cleanup\data\data_no_packing_all\data_col_no_packing.xlsx", 
    sheet_name = r"no_packing",
    index=False)

# %%
df1
# Out:
#     flowrate_percent  width_ns  freq_kHz  voltage_kV temp_C  height  \
# 0               0.35       240       6.0           8     na       2
# 1               0.35       180       6.0          10     na       2
# 2               0.35       180       2.0          10     na       2
# 3               0.35       140       8.0          10     na       2
# 4               0.35       140       2.0          11     na       2
# 5               0.35       140       2.0          12     na       2
# 6               0.35       240       1.0          10     na       2
# 7               0.35        60      10.0          14     na       2
# 8               0.35        60      10.0          12     na       2
# 9               0.65       120      10.0           8     na       2
# 10              0.65       120       1.5          13     na       2
# 11              0.65       240       1.0          10     na       2
# 12              0.65       240       3.0          10     na       2
# 13              0.65       100       3.0          12     na       2
# 14              0.65       100       5.0          12     na       2
# 15              0.65       140       5.0          12     na       2
# 16              0.65       180       0.5          12     na       2
# 17              1.00       120       2.0          14     na       2
# 18              1.00        60       8.0          14     na       2
# 19              1.00       240      10.0           8     na       2
# 20              1.00       100      10.0          10     na       2
# 21              1.00       180       1.0          12     na       2
# 22              1.00       100      10.0          12     na       2
# 23              1.00       140       5.0          12     na       2
# 24              0.35       200       4.0          14     na       3
# 25              0.35       200       4.0          14     na       3
# 26              0.65       100      10.0          10     na       3
# 27              0.65       160      10.0          10     na       3
# 28              0.65       160       7.0          12     na       3
# 29              0.65       200       4.0          12     na       3
# 30              0.65       100       4.0          14     na       3
# 31              0.65       140       4.0          14     na       3
# 32              0.65       200       1.0          14     na       3
# 33              0.65       180      10.0          10     na       5
# 34              0.65       180      10.0          14     na       5
# 35              0.65       240      10.0          10     na       5
# 36              0.65       180       6.0          12     na       5
# 37              0.65       240       5.0          12     na       5
# 38              0.65       240      10.0          12     na       5
# 39              0.65       140       6.0          12     na       5
# 40              0.65       140      10.0          12     na       5
# 41              0.65       140      10.0          14     na       5
# 42              0.65       180       6.0          14     na       5
# 43              0.65       240       2.0          14     na       5
# 44              0.65       240       3.0          14     na       5
# 45              0.65       180      10.0          12     na       5
# 46              0.65       140      10.0          10     na       5
# 47              0.65       180      10.0          10     na       5
#
#     packing size  power_w  706_667_587_K  706_587_K  706_728_K  706_728_587_K  \
# 0              0      NaN            NaN        NaN       1424            NaN
# 1              0      NaN            NaN        NaN       1407            NaN
# 2              0      NaN            NaN        NaN       1747            NaN
# 3              0      NaN            NaN        NaN       1864            NaN
# 4              0      NaN            NaN        NaN       1912            NaN
# 5              0      NaN            NaN        NaN       1453            NaN
# 6              0      NaN            NaN        NaN       1390            NaN
# 7              0      NaN            NaN        NaN       1764            NaN
# 8              0      NaN            NaN        NaN       1896            NaN
# 9              0      NaN            NaN        NaN       2239            NaN
# 10             0      NaN            NaN        NaN       1512            NaN
# 11             0      NaN            NaN        NaN       1688            NaN
# 12             0      NaN            NaN        NaN       1325            NaN
# 13             0      NaN            NaN        NaN       2002            NaN
# 14             0      NaN            NaN        NaN       1732            NaN
# 15             0      NaN            NaN        NaN       1330            NaN
# 16             0      NaN            NaN        NaN       1670            NaN
# 17             0      NaN            NaN        NaN       1366            NaN
# 18             0      NaN            NaN        NaN       1504            NaN
# 19             0      NaN            NaN        NaN       1753            NaN
# 20             0      NaN            NaN        NaN       1609            NaN
# 21             0      NaN            NaN        NaN       1364            NaN
# 22             0      NaN            NaN        NaN       1365            NaN
# 23             0      NaN            NaN        NaN       1412            NaN
# 24             0      NaN            NaN        NaN       1407            NaN
# 25             0      NaN            NaN        NaN       1423            NaN
# 26             0      NaN            NaN        NaN       1762            NaN
# 27             0      NaN            NaN        NaN       1935            NaN
# 28             0      NaN            NaN        NaN       1895            NaN
# 29             0      NaN            NaN        NaN       2204            NaN
# 30             0      NaN            NaN        NaN       2069            NaN
# 31             0      NaN            NaN        NaN       1528            NaN
# 32             0      NaN            NaN        NaN       1777            NaN
# 33             0      NaN            NaN        NaN       1765            NaN
# 34             0      NaN            NaN        NaN       1672            NaN
# 35             0      NaN            NaN        NaN       1889            NaN
# 36             0      NaN            NaN        NaN       2195            NaN
# 37             0      NaN            NaN        NaN       2211            NaN
# 38             0      NaN            NaN        NaN       1861            NaN
# 39             0      NaN            NaN        NaN       2204            NaN
# 40             0      NaN            NaN        NaN       1724            NaN
# 41             0      NaN            NaN        NaN       1657            NaN
# 42             0      NaN            NaN        NaN       2035            NaN
# 43             0      NaN            NaN        NaN       3303            NaN
# 44             0      NaN            NaN        NaN       2717            NaN
# 45             0      NaN            NaN        NaN       1723            NaN
# 46             0      NaN            NaN        NaN       2550            NaN
# 47             0      NaN            NaN        NaN       3011            NaN
#
#              signature  RF_direct_best  mis
# 0   OES_20231013165342             NaN  NaN
# 1   OES_20231013170219             NaN  NaN
# 2   OES_20231013171848             NaN  NaN
# 3   OES_20231013173923             NaN  NaN
# 4   OES_20231013174758             NaN  NaN
# 5   OES_20231013175708             NaN  NaN
# 6   OES_20231013180609             NaN  NaN
# 7   OES_20231013181507             NaN  NaN
# 8   OES_20231013182414             NaN  NaN
# 9   OES_20231014163744             NaN  NaN
# 10  OES_20231014164607             NaN  NaN
# 11  OES_20231014172028             NaN  NaN
# 12  OES_20231014175132             NaN  NaN
# 13  OES_20231014180833             NaN  NaN
# 14  OES_20231014181819             NaN  NaN
# 15  OES_20231014182645             NaN  NaN
# 16  OES_20231014184855             NaN  NaN
# 17  OES_20231014214741             NaN  NaN
# 18  OES_20231014220428             NaN  NaN
# 19  OES_20231014230141             NaN  NaN
# 20  OES_20231014232833             NaN  NaN
# 21  OES_20231014234418             NaN  NaN
# 22  OES_20231014235302             NaN  NaN
# 23  OES_20231015001744             NaN  NaN
# 24  OES_20231015230932             NaN  NaN
# 25  OES_20231015231440             NaN  NaN
# 26  OES_20231016225458             NaN  NaN
# 27  OES_20231017125749             NaN  NaN
# 28  OES_20231017163243             NaN  NaN
# 29  OES_20231017172255             NaN  NaN
# 30  OES_20231017174107             NaN  NaN
# 31  OES_20231017182130             NaN  NaN
# 32  OES_20231017183006             NaN  NaN
# 33  OES_20231018145805             NaN  NaN
# 34  OES_20231018151858             NaN  NaN
# 35  OES_20231018162007             NaN  NaN
# 36  OES_20231018175256             NaN  NaN
# 37  OES_20231018180921             NaN  NaN
# 38  OES_20231018181810             NaN  NaN
# 39  OES_20231018183604             NaN  NaN
# 40  OES_20231018184405             NaN  NaN
# 41  OES_20231018191512             NaN  NaN
# 42  OES_20231018200236             NaN  NaN
# 43  OES_20231018203543             NaN  NaN
# 44  OES_20231018204405             NaN  NaN
# 45  OES_20231017222652             NaN  NaN
# 46  OES_20231017223657             NaN  NaN
# 47  OES_20231018140510             NaN  NaN
