# %%
import numpy as np
import scipy.integrate as integrate
import matplotlib.pyplot as plt
import scipy.optimize as sopt
import pandas as pd
import os
from pyomo.environ import *
from idaes.core.solvers import get_solver
import pandas as pd

# %%
# got it means that it is in the excel sheet already

# Q_a = float(Qa[index])   #got it
# Q_b = float(Qb[index])   # got it
# T_e = Te[index]          # got it
# t_a = float(time_col[index,0]) #seconds    got it
# t_b = float(time_col[index,1]) #seconds    got it
# t_c = float(1/freq[index]-t_a-t_b)        #will be calculated in place
# t_b = t_c+t_b                             # will be calcullated in place
# V_p_ta = float(Vipa[index]/t_a) #volts  #will be calculated in place
# V_p_tb = float(Vipb[index]/(t_b+t_c))  #volts   # will be calculated in place
# V_p_tc = 0.0                                   # will be assigned in place
# Flow = flowrate[index]*6*(10**-5)-0.0001 #convert from % to m^3/s, see exccel "flow_calibration..."
# E = float(E_abs[index])                       # got it
# ns = width_ns[index]                          # got it
# temp_C_gas = temp_C[index]                    # will be set.
# frequency = freq[index]                       # got it
# volt = voltage[index]                         #got it
# sign = signature[index]                       # got it

# %%
from PyDBDdim.utils import DatasetProcess
DBD = DatasetProcess(r'C:\Users\vvmil\Documents\Python_Vmil\Jupyter_Notebooks\Plasma_He_calcs\data\data_3cm_23mm_packing\3cm_23mm_packing')
signature_list = DBD.folder_col
time_col, _= DBD.current_segment()
time_col = np.array(time_col)
t_index = np.array(_)
Vipab, Qab = DBD.get_two_region_VI()
Pabs_kj = DBD.int_power #this is actually worthless but just being complete.
E_abs = DBD.get_plasma_E() #joules?
#print(Vipab)
#print(Qab)
#print(time_col)
#print(_)
#print(signature_list)

Vipa = np.reshape(Vipab[:,0],(Vipab.shape[0],1))
Vipb = np.reshape(Vipab[:,1],(Vipab.shape[0],1))
Qa = np.reshape(Qab[:,0],(Qab.shape[0],1))
Qb = np.reshape(Qab[:,1],(Qab.shape[0],1))
t_a = np.reshape(time_col[:,0],(Qab.shape[0],1))
t_b = np.reshape(time_col[:,1],(Qab.shape[0],1))
Pabs_kj = np.reshape(Pabs_kj, (Pabs_kj.shape[0],1))
E_abs = np.reshape(E_abs, (E_abs.shape[0],1))
print(Pabs_kj.shape)
print(t_a.shape)
print(t_b.shape)
print(Qa.shape)
print(Qb.shape)
print(Vipa.shape)
print(Vipb.shape)
print(E_abs.shape)



matrix = np.hstack((Vipa, Vipb, Qa, Qb, Pabs_kj, E_abs, t_a, t_b))
variables = ['Vipa_Vs', 'Vipb_Vs', 'Qa_As', 'Qb_As', 'Pabs_kJ','E_abs','ta_s', 'tb_s']
# Out:
# (51, 1)
# (51, 1)
# (51, 1)
# (51, 1)
# (51, 1)
# (51, 1)
# (51, 1)
# (51, 1)

# %%
print(matrix.shape)
print(Qa.shape)
print(Vipa.shape)
# Out:
# (51, 8)
# (51, 1)
# (51, 1)

# %%
print(signature_list)
# Out:
# ['OES_20231102161943', 'OES_20231102164613', 'OES_20231102171432', 'OES_20231102172202', 'OES_20231102172949', 'OES_20231102173858', 'OES_20231102175610', 'OES_20231102180439', 'OES_20231102182203', 'OES_20231102183035', 'OES_20231102184031', 'OES_20231102190917', 'OES_20231102193836', 'OES_20231102194928', 'OES_20231102200251', 'OES_20231102203108', 'OES_20231102204201', 'OES_20231102204956', 'OES_20231102205725', 'OES_20231102210512', 'OES_20231102211341', 'OES_20231102212215', 'OES_20231102213022', 'OES_20231102213902', 'OES_20231102214706', 'OES_20231103132824', 'OES_20231103133556', 'OES_20231103134345', 'OES_20231103135241', 'OES_20231103155030', 'OES_20231103160046', 'OES_20231103160741', 'OES_20231103162105', 'OES_20231103163025', 'OES_20231103164903', 'OES_20231103165857', 'OES_20231103194832', 'OES_20231103195639', 'OES_20231103201533', 'OES_20231103202331', 'OES_20231103203143', 'OES_20231103203923', 'OES_20231103205023', 'OES_20231103205821', 'OES_20231103210634', 'OES_20231103211724', 'OES_20231103212636', 'OES_20231103213610', 'OES_20231103214539', 'OES_20231103215633', 'OES_20231103220957']

# %%
# Put this in three parts:
#1) generate data frame from data above
#2) generate data frame from existing excel with data inputs and Temperature
#3) delete redundant, empty columns in old excel
#4) pd.merg the data frames
#5) load into a new excel


#1 df
df0 = pd.DataFrame(data=matrix,columns=[variables[i] for i in range(0,len(variables))]) #first sheet, list dimension vector
df0['signature_dbd'] = signature_list
#df1 = pd.DataFrame(data=signature_list,columns=['signature']) #second sheet, list nullspace vectors and associated variables



# df from existing excel

file_path = r"C:\Users\vvmil\Documents\Python_Vmil\Jupyter_Notebooks\Plasma_He_calcs\data\data_3cm_23mm_packing\data_col_vvm.xlsx"
df1 = pd.read_excel(file_path, sheet_name = r"3cm_23mm_good")
df1 = df1.drop(columns = variables, errors = 'ignore')

#merge them
merged_df = pd.merge(df1, df0, left_on="signature", right_on="signature_dbd", how="inner")

merged_df.to_excel(
    r"C:\Users\vvmil\Documents\Python_Vmil\Jupyter_Notebooks\Plasma_He_calcs_cleanup\data\data_3cm_23mm_packing\data_col_vvm_plus_dbd.xlsx", 
    sheet_name = r"3cm_23mm",
    index=False)

# %%
df1
# Out:
#     flowrate_percent  width_ns  freq_kHz  voltage_kV temp_C  height  \
# 0               0.65       120        10          14     na       3
# 1               0.65       220         5          14     na       3
# 2               0.65       180         2          10     na       3
# 3               0.65       180         5          10     na       3
# 4               0.65       180        10          10     na       3
# 5               0.65       220         2          10     na       3
# 6               0.65       220         5          10     na       3
# 7               0.65       220        10          10     na       3
# 8               0.65       120         2          12     na       3
# 9               0.65       120         5          12     na       3
# 10              0.65       120        10          12     na       3
# 11              0.65       260         2          10     na       3
# 12              0.65       160         2          12     na       3
# 13              0.65       160         5          12     na       3
# 14              0.65       160        10          12     na       3
# 15              0.65       260         5          10     na       3
# 16              0.65       260        10          10     na       3
# 17              0.65       200         2          12     na       3
# 18              0.65       200         1          12     na       3
# 19              0.65       200         5          12     na       3
# 20              0.65       200        10          12     na       3
# 21              0.65       240         1          12     na       3
# 22              0.65       240         3          12     na       3
# 23              0.65       240        10          12     na       3
# 24              0.65       100         1          14     na       3
# 25              0.65       100         3          14     na       3
# 26              0.65       100        10          14     na       3
# 27              0.65       140         1          14     na       3
# 28              0.65       140         3          14     na       3
# 29              0.65       140         5          14     na       3
# 30              0.65       140         7          14     na       3
# 31              0.65       140        10          14     na       3
# 32              0.65       200         1          14     na       3
# 33              0.65       200         3          14     na       3
# 34              0.65       200         7          14     na       3
# 35              0.65       200        10          14     na       3
# 36              0.65       240         1          14     na       3
# 37              0.65       240         3          14     na       3
# 38              0.65       240         7          14     na       3
# 39              0.65       240        10          14     na       3
# 40              0.65       100         1          16     na       3
# 41              0.65       100         3          16     na       3
# 42              0.65       100         7          16     na       3
# 43              0.65       100        10          16     na       3
# 44              0.65       140         1          16     na       3
# 45              0.65       140         3          16     na       3
# 46              0.65       140         6          16     na       3
# 47              0.65        60         2          16     na       3
# 48              0.65        60         5          16     na       3
# 49              0.65        60        10          16     na       3
#
#     packing size  power_w  706_667_587_K  706_587_K  706_728_K  \
# 0            2.3      NaN            NaN        NaN       1408
# 1            2.3      NaN            NaN        NaN       1399
# 2            2.3      NaN            NaN        NaN       1496
# 3            2.3      NaN            NaN        NaN       1395
# 4            2.3      NaN            NaN        NaN       1415
# 5            2.3      NaN            NaN        NaN       1566
# 6            2.3      NaN            NaN        NaN       1469
# 7            2.3      NaN            NaN        NaN       1398
# 8            2.3      NaN            NaN        NaN       1557
# 9            2.3      NaN            NaN        NaN       1420
# 10           2.3      NaN            NaN        NaN       1397
# 11           2.3      NaN            NaN        NaN       1395
# 12           2.3      NaN            NaN        NaN       1339
# 13           2.3      NaN            NaN        NaN       1376
# 14           2.3      NaN            NaN        NaN       1357
# 15           2.3      NaN            NaN        NaN       1380
# 16           2.3      NaN            NaN        NaN       1390
# 17           2.3      NaN            NaN        NaN       1414
# 18           2.3      NaN            NaN        NaN       1478
# 19           2.3      NaN            NaN        NaN       1356
# 20           2.3      NaN            NaN        NaN       1357
# 21           2.3      NaN            NaN        NaN       1468
# 22           2.3      NaN            NaN        NaN       1423
# 23           2.3      NaN            NaN        NaN       1383
# 24           2.3      NaN            NaN        NaN       1617
# 25           2.3      NaN            NaN        NaN       1428
# 26           2.3      NaN            NaN        NaN       1453
# 27           2.3      NaN            NaN        NaN       1538
# 28           2.3      NaN            NaN        NaN       1399
# 29           2.3      NaN            NaN        NaN       1381
# 30           2.3      NaN            NaN        NaN       1388
# 31           2.3      NaN            NaN        NaN       1379
# 32           2.3      NaN            NaN        NaN       1451
# 33           2.3      NaN            NaN        NaN       1392
# 34           2.3      NaN            NaN        NaN       1371
# 35           2.3      NaN            NaN        NaN       1360
# 36           2.3      NaN            NaN        NaN       1372
# 37           2.3      NaN            NaN        NaN       1386
# 38           2.3      NaN            NaN        NaN       1360
# 39           2.3      NaN            NaN        NaN       1353
# 40           2.3      NaN            NaN        NaN       1438
# 41           2.3      NaN            NaN        NaN       1395
# 42           2.3      NaN            NaN        NaN       1477
# 43           2.3      NaN            NaN        NaN       1424
# 44           2.3      NaN            NaN        NaN       1382
# 45           2.3      NaN            NaN        NaN       1386
# 46           2.3      NaN            NaN        NaN       1429
# 47           2.3      NaN            NaN        NaN       1426
# 48           2.3      NaN            NaN        NaN       1424
# 49           2.3      NaN            NaN        NaN       1400
#
#         706_728_587_K           signature  Pabs_kJ  RF_direct_best  mis
# 0                 NaN  OES_20231102161943      NaN             NaN  NaN
# 1                 NaN  OES_20231102164613      NaN             NaN  NaN
# 2                 NaN  OES_20231102171432      NaN             NaN  NaN
# 3                 NaN  OES_20231102172202      NaN             NaN  NaN
# 4                 NaN  OES_20231102172949      NaN             NaN  NaN
# 5                 NaN  OES_20231102173858      NaN             NaN  NaN
# 6                 NaN  OES_20231102175610      NaN             NaN  NaN
# 7                 NaN  OES_20231102180439      NaN             NaN  NaN
# 8                 NaN  OES_20231102182203      NaN             NaN  NaN
# 9                 NaN  OES_20231102183035      NaN             NaN  NaN
# 10                NaN  OES_20231102184031      NaN             NaN  NaN
# 11                NaN  OES_20231102190917      NaN             NaN  NaN
# 12                NaN  OES_20231102193836      NaN             NaN  NaN
# 13                NaN  OES_20231102194928      NaN             NaN  NaN
# 14                NaN  OES_20231102200251      NaN             NaN  NaN
# 15                NaN  OES_20231102204201      NaN             NaN  NaN
# 16  ? Missing voltage  OES_20231102204956      NaN             NaN  NaN
# 17                NaN  OES_20231102205725      NaN             NaN  NaN
# 18                NaN  OES_20231102210512      NaN             NaN  NaN
# 19                NaN  OES_20231102211341      NaN             NaN  NaN
# 20                NaN  OES_20231102212215      NaN             NaN  NaN
# 21                NaN  OES_20231102213022      NaN             NaN  NaN
# 22                NaN  OES_20231102213902      NaN             NaN  NaN
# 23                NaN  OES_20231102214706      NaN             NaN  NaN
# 24                NaN  OES_20231103132824      NaN             NaN  NaN
# 25                NaN  OES_20231103133556      NaN             NaN  NaN
# 26                NaN  OES_20231103134345      NaN             NaN  NaN
# 27                NaN  OES_20231103135241      NaN             NaN  NaN
# 28                NaN  OES_20231103155030      NaN             NaN  NaN
# 29                NaN  OES_20231103160046      NaN             NaN  NaN
# 30                NaN  OES_20231103160741      NaN             NaN  NaN
# 31                NaN  OES_20231103162105      NaN             NaN  NaN
# 32                NaN  OES_20231103163025      NaN             NaN  NaN
# 33                NaN  OES_20231103164903      NaN             NaN  NaN
# 34                NaN  OES_20231103165857      NaN             NaN  NaN
# 35                NaN  OES_20231103194832      NaN             NaN  NaN
# 36                NaN  OES_20231103195639      NaN             NaN  NaN
# 37                NaN  OES_20231103201533      NaN             NaN  NaN
# 38                NaN  OES_20231103202331      NaN             NaN  NaN
# 39                NaN  OES_20231103203143      NaN             NaN  NaN
# 40                NaN  OES_20231103203923      NaN             NaN  NaN
# 41                NaN  OES_20231103205023      NaN             NaN  NaN
# 42                NaN  OES_20231103205821      NaN             NaN  NaN
# 43                NaN  OES_20231103210634      NaN             NaN  NaN
# 44                NaN  OES_20231103211724      NaN             NaN  NaN
# 45                NaN  OES_20231103212636      NaN             NaN  NaN
# 46                NaN  OES_20231103213610      NaN             NaN  NaN
# 47                NaN  OES_20231103214539      NaN             NaN  NaN
# 48                NaN  OES_20231103215633      NaN             NaN  NaN
# 49                NaN  OES_20231103220957      NaN             NaN  NaN
